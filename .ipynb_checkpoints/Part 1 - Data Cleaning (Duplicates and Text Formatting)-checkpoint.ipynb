# %% [markdown]
# # Houses and Empty Lots for Sale in New Brunswick (as of June 12, 2020)
#
# In this project, I scraped data from this [website](https://www.point2homes.com/CA/Real-Estate-Listings/NB.html) which lists houses and
# empty lots for sale. The selling price is listed along with the lot size. For houses, the number of bedrooms, bathrooms, the house size the house type are also given.
#
# ## 1. Data Cleaning (Duplicates and Text Formatting)

# %%
# load libraries
import numpy as np
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm

# read csv file
df = pd.read_csv("houseprices_nbf.csv")
df.head(5)
# Out:
#                                              Address  Beds  Baths  House Size  \
# 0   10 Robin Dr, Fredericton, New Brunswick, E3C 1K6   5.0    2.0      1600.0
# 1        03-2 Glebe Rd, Saint Andrews, New Brunswick   NaN    NaN         NaN
# 2  62 Parkin Street, Salisbury, New Brunswick, E4...   3.0    2.0      3790.0
# 3         14 Murray Lane, St. Andrews, New Brunswick   4.0    2.0      2200.0
# 4    140 Orleans St., Dieppe, New Brunswick, E1A 1W9   4.0    3.0      2808.0
#
#    Lot Size                                     Type   Price
# 0     0.177  \r\n            Residential\r\n          259900
# 1     1.140  \r\n            Residential\r\n           11400
# 2     0.850  \r\n            Residential\r\n          549900
# 3     1.150  \r\n            Residential\r\n          449500
# 4     0.124  \r\n            Residential\r\n          236900

# %%
# df['Type'] has '\r\n' at the beginning and end, so we remove it
df['Type'] = df['Type'].str.replace(r'\r\n','')

df.head(5)
# Out:
#                                              Address  Beds  Baths  House Size  \
# 0   10 Robin Dr, Fredericton, New Brunswick, E3C 1K6   5.0    2.0      1600.0
# 1        03-2 Glebe Rd, Saint Andrews, New Brunswick   NaN    NaN         NaN
# 2  62 Parkin Street, Salisbury, New Brunswick, E4...   3.0    2.0      3790.0
# 3         14 Murray Lane, St. Andrews, New Brunswick   4.0    2.0      2200.0
# 4    140 Orleans St., Dieppe, New Brunswick, E1A 1W9   4.0    3.0      2808.0
#
#    Lot Size                             Type   Price
# 0     0.177              Residential          259900
# 1     1.140              Residential           11400
# 2     0.850              Residential          549900
# 3     1.150              Residential          449500
# 4     0.124              Residential          236900

# %% [markdown]
# It would not make sense to feed in the complete address to our machine learning algorithm. As such we would only be getting the postal code. If there is no postal code, fortunately, we can get the postal code of a given address on [www.geocoder.ca](http://www.geocoder.ca).

# %%
# Create column for postal code
df['Postal Code'] = np.nan

for index, address in tqdm(df['Address'].items(),total=len(df['Address'])):
    if address[-7] == 'E' and address[-6].isnumeric():
        df['Postal Code'][index] = address[-7:]
    else:
        print(address)
        post_data = {'locate': address}
        url = 'http://www.geocoder.ca'
        html_result = requests.post(url, data=post_data).text
        soup = BeautifulSoup(html_result,'lxml')
        
        complete_address = soup.find('title').text
        postal_code = re.search('E[0-9][A-Z][0-9][A-Z][0-9]',complete_address)
        print(postal_code is None)
        
        if postal_code is not None:
            print(postal_code.group(0))
            df['Postal Code'][index] = postal_code.group(0)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=720.0), HTML(value='')))
# /Users/renzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/renzoflores/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# 03-2 Glebe Rd, Saint Andrews, New Brunswick
# False
# E5B2Z5
# 14 Murray Lane, St. Andrews, New Brunswick
# /Users/renzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# True
# 41 Eagle's Passage, Greater Saint Andrews, New Brunswick
# False
# E5B0A9
# 7725 Rte 515, Saint-Paul, New Brunswick
# False
# E4T3R4
# 133 Daigle Rd., Pointe-Sapin, New Brunswick
# False
# E9A1T7
# 294 Carleton St, Saint Andrews, New Brunswick
# False
# E5B1P2
# 3574 Route 127, Saint Andrews, New Brunswick
# False
# E5B2W5
# 175 Daigle Rd, Pointe-Sapin, New Brunswick
# False
# E9A1T7
# 5185 Route 127, St. Andrews, New Brunswick
# False
# E5B3A7
# 48 Augustus St, Saint Andrews, New Brunswick
# False
# E5B2E7
# 83 Don-De Dieu Dr, Bayside, New Brunswick
# False
# E5B3Y2
# 38 Ernest St, Saint Andrews, New Brunswick
# False
# E5B2E1
# 45 Argyle Court, Saint Andrews, New Brunswick
# False
# E5B2H7
# 133 Daigle Rd., Pointe-Sapin, New Brunswick
# False
# E9A1T7
# 117 Anne's Acres, Bayfield, NB, Murray Corner, New Brunswick
# False
# E4M3K8
# 45 Argyle Court, Saint Andrews, New Brunswick
# False
# E5B2H7
# 38 Ernest St, Saint Andrews, New Brunswick
# False
# E5B2E1
# 41 Eagle's Passage, Greater Saint Andrews, New Brunswick
# False
# E5B0A9
# 3574 Route 127, Saint Andrews, New Brunswick
# False
# E5B2W5
# 66 Neville Street, Fredericton, New Brunswick, E3A4Z5
# False
# E3A4Z5
# 21 Chalets LANE, Richibucto, New Brunswick
# False
# E4W5W9
# - Russiantown Road, Greater Elgin, New Brunswick
# False
# E4Z2A8
# 103 Canaan Drive, Rusagonis - Waasis, New Brunswick
# False
# E3B0B6
# 26 Brickyard Road, Lepreau, New Brunswick
# False
# E5J1E4
# 40 Damien Unit 2, Dieppe, New Brunswick, E1A7T2
# False
# E1A7T2
# 60 T J McMackin, Greater Salisbury, New Brunswick
# False
# E4J2N5
# 298 French Lake Road, French Lake, New Brunswick
# False
# E2V4E2
# 469 Belleisle Shore Road, Kars, New Brunswick
# False
# E5T3E9
# 181 Route 776, Grand Manan, New Brunswick, E5G1A4
# False
# E5G1A4
# 421 Ryan RD, Moncton, New Brunswick, E1C2W2
# False
# E1C2W2
# 224 Chapman Road, Newcastle Centre, New Brunswick
# False
# E4B2M1
# 351 Beausejour, Dieppe, New Brunswick, E1A1Y6
# False
# E1A1Y6
# 43 Camden CRES, Moncton, New Brunswick, E1E4S6
# False
# E1E4S6
# 305 Hampton Road, Quispamsis, New Brunswick, E2M4M9
# False
# E2M4M9
# 15 Tiffany AVE, Bouctouche, New Brunswick, E4S3X2
# False
# E4S3X2
# 15 Laity DR, Upper Coverdale/Turtle Creek, New Brunswick
# False
# E1J0E3
# 167 Hillcrest Drive, Island View Heights, New Brunswick
# False
# E2M4C4
# 33 Bellerive RD, Shemogue, New Brunswick
# False
# E4N2V5
# 243 Prince William Street Unit 117, Saint John Centre, New Brunswick
# False
# E2L0C6
# 50 Old Bay Road, Oak Bay, New Brunswick
# False
# E3L3W8
# 159 York ST, Moncton, New Brunswick, E1C2Z1
# False
# E1C2Z1
# 81 Riverview Drive, Saint John West, New Brunswick
# False
# E2M2M5
# 3 Wharf Road, Burton, New Brunswick
# False
# E2V3J7
# 93 Savannah DR, Moncton, New Brunswick, E1A0J5
# False
# E1A0J5
# 1790 Bridge Street, Bathurst, New Brunswick, E2A5X5
# False
# E2A5X5
# 600 Crafts Cove Road, Wickham, New Brunswick
# False
# E5T4Y6
# 471 Paturel ST, Shediac, New Brunswick, E4P2L2
# False
# E4P2L2
# - Gooseberry Cove Road, Musquash, New Brunswick
# False
# E2M3G5
# 1026 Barachois, Dieppe, New Brunswick, E1A7S8
# False
# E1A7S8
# 284 Tobias AVE, Riverview, New Brunswick, E1B4W1
# False
# E1B4W1
# 13 Alcorn ST, Lakeville, New Brunswick
# False
# E1H1H5
# 59 Nugent ST, Dieppe, New Brunswick, E1A0S7
# False
# E1A0S7
# 25 Burnett Street, Oromocto, New Brunswick, E2V0J6
# False
# E2V0J6
# 9 Hopper, Moncton, New Brunswick, E1C8Y2
# False
# E1C8Y2
# 2358 Route 490, Ammon, New Brunswick, E1G4R7
# False
# E1G4R7
# 183 Riverside Drive, Fredericton, New Brunswick, E3A6R1
# False
# E3A6R1
# 87 Ridgeline Crescent, Fredericton, New Brunswick, E3C0E0
# False
# E3C0E0
# 61 Mailhot, Moncton, New Brunswick, E1G1S6
# False
# E1G1S6
# 163 Riverside Drive, Fredericton, New Brunswick, E3A6R1
# False
# E3A6R1
# 228 Greenwood Drive, Fredericton, New Brunswick, E3A3T7
# False
# E3A3T7
# 1836 Route 620, Estey's Bridge, New Brunswick
# False
# E3G6N1
# 22 Pebble Creek, Moncton, New Brunswick, E1E0C8
# False
# E1E0C8
# 33 Bellerive RD, Shemogue, New Brunswick
# False
# E4N2V5
# Lot 14-5 Route 112, Canaan Forks, New Brunswick
# False
# E4Z6B2
# 409 Paturel, Shediac, New Brunswick, E4P2L2
# False
# E4P2L2
# 13 Sussex Drive, Pokiok, New Brunswick
# True
# - Access Road, Greater Saint Martins, New Brunswick
# False
# E5R1L8
# 2 Bickerton AVE, Sackville, New Brunswick, E4L3M7
# False
# E4L3M7
# 15 Laity DR, Upper Coverdale/Turtle Creek, New Brunswick
# False
# E1J0E3
# Lot Boyne Road, Hoyt, New Brunswick
# False
# E5L2G5
# 180 Marie, Beresford, New Brunswick, E8K1P8
# False
# E8K1P8
# 3 Route 1127, Harvey, New Brunswick, E6K2S5
# False
# E6K2S5
# 87 Ridgeline Crescent, Fredericton, New Brunswick, E3C0E0
# False
# E3C0E0
# 1790 Bridge Street, Bathurst, New Brunswick, E2A5X5
# False
# E2A5X5
# 167 Hillcrest Drive, Island View Heights, New Brunswick
# False
# E2M4C4
# 469 Belleisle Shore Road, Kars, New Brunswick
# False
# E5T3E9
# 21 Elgin Road, Forest Hills, New Brunswick
# False
# E2Y2Y6
# 183 Riverside Drive, Fredericton, New Brunswick, E3A6R1
# False
# E3A6R1
# 66 Neville Street, Fredericton, New Brunswick, E3A4Z5
# False
# E3A4Z5
# 60 T J McMackin, Greater Salisbury, New Brunswick
# False
# E4J2N5
# 102 Glebe Road, Chamcook, New Brunswick
# False
# E5B3C3
# 452 Douglas Avenue, Indiantown, New Brunswick
# False
# E2K1G1
# 138 Nevers Road, Nevers Road, New Brunswick
# True
# 9 Hopper, Moncton, New Brunswick, E1C8Y2
# False
# E1C8Y2
# 59 Nugent ST, Dieppe, New Brunswick, E1A0S7
# False
# E1A0S7
# 50 Old Bay Road, Oak Bay, New Brunswick
# False
# E3L3W8
# 21 Chalets LANE, Richibucto, New Brunswick
# False
# E4W5W9
# 224 Chapman Road, Newcastle Centre, New Brunswick
# False
# E4B2M1
# - Gooseberry Cove Road, Musquash, New Brunswick
# False
# E2M3G5
# 40 Damien Unit 2, Dieppe, New Brunswick, E1A7T2
# False
# E1A7T2
# 284 Tobias AVE, Riverview, New Brunswick, E1B4W1
# False
# E1B4W1
# 305 Hampton Road, Quispamsis, New Brunswick, E2M4M9
# False
# E2M4M9
# 53 Evergreen Street, Fredericton, New Brunswick, E3B6N1
# False
# E3B6N1
# 1226 Riverside Drive, Bathurst, New Brunswick, E2A4X2
# False
# E2A4X2
# 61 Mailhot, Moncton, New Brunswick, E1G1S6
# False
# E1G1S6
# 8 Beattie, Rexton, New Brunswick, E4W1W5
# False
# E4W1W5
# 16 Rockingstone Drive, Bayshore, New Brunswick
# True
# 2358 Route 490, Ammon, New Brunswick, E1G4R7
# False
# E1G4R7
# 351 Beausejour, Dieppe, New Brunswick, E1A1Y6
# False
# E1A1Y6
# 421 Ryan RD, Moncton, New Brunswick, E1C2W2
# False
# E1C2W2
# 1828 Westfield Road, Acamac, New Brunswick
# False
# E2M6N1
# 13 Alcorn ST, Lakeville, New Brunswick
# False
# E1H1H5
# 103 Canaan Drive, Rusagonis - Waasis, New Brunswick
# False
# E3B0B6
# 150 Alma Unit 2, Moncton, New Brunswick, E1C4Y7
# False
# E1C4Y7
# 93 Savannah DR, Moncton, New Brunswick, E1A0J5
# False
# E1A0J5
# 3751 Principale Street, Baker - Brook, New Brunswick
# True
# Lot Route 490, Fords Mills, New Brunswick
# True
# 400 East Glassvile Road, Glassville, New Brunswick
# False
# E7L1W1
# 44 Silas Lewis RD, Greater Salisbury, New Brunswick
# False
# E4J3B9
# 207 King Street Unit 6, Saint John Centre, New Brunswick
# False
# E2L1H2
# 65 Meghan, Riverview, New Brunswick, E1B4E4
# False
# E1B4E4
# 368 Princess, Bathurst, New Brunswick, E2A2R5
# False
# E2A2R5
# 81 Riverview Drive, Saint John West, New Brunswick
# False
# E2M2M5
# 40 Rose Street, St. Stephen, New Brunswick
# False
# E3L2P9
# 591 Route 935, Wood Point, NB, Greater Sackville, New Brunswick
# False
# E4L2K7
# Lamberts Rd, Lambert's Cove, Deer Island, New Brunswick
# False
# E5V1E2
# 81 Union Street, St. Stephen, New Brunswick
# False
# E3L1V2
# 23 verte, Dieppe, New Brunswick, E1A2E1
# False
# E1A2E1
# 178 C K Justason Lane, Pennfield, New Brunswick
# False
# E5H1S2
# 178 C K Justason Lane, Pennfield, New Brunswick
# False
# E5H1S2
# 400 South Canaan Road, South Canaan, New Brunswick
# False
# E4C4J2
# - Route 750, Dennis-Weston, New Brunswick
# True
# 12-9 Hills Point Road, Oak Bay, New Brunswick
# False
# E3L4H7
# 93 Bethany Drive, Rusagonis - Waasis, New Brunswick
# False
# E3B8W6
# 1301 Route 127, Rollingdam, New Brunswick
# False
# E5A2W4
# Lot 18-2 Route 960, Cape Spear, NB, Port Elgin, New Brunswick
# False
# E4M2S1
# Woodlot on Route 118, Miramichi, New Brunswick
# True
# 2479 Route 106, Steeves Mountain, New Brunswick
# False
# E1G4B3
# Lot Goymers Lane, Bay du Vin, Black River - Hardwicke, New Brunswick
# True
# Lot Poirier Office RD Notre Dame, Irishtown, New Brunswick
# True
# 15 Dow Street, St. Stephen, New Brunswick
# False
# E3L1R4
# 35 Morey Brow Road, Deer Island, New Brunswick
# False
# E5V1R5
# - Mcgaw Hill Route 745, Oak Hill, New Brunswick
# True
# 96 Todds Point Road, Saint Stephen, New Brunswick
# False
# E3L3P9
# 15-4 Winterport Way, Fredericton, New Brunswick
# False
# E3A1X5
# 23 Better Homes Dr, Greater New Maryland, New Brunswick
# False
# E3C0G6
# 92 Marks Street, St. Stephen, New Brunswick
# False
# E3L2B5
# 234 Scott Road, Saint Stephen, New Brunswick
# False
# E5A1P4
# 735 Bellefond Road, Miramichi, New Brunswick
# False
# E1V4V1
# 15-6 Winterport Way, Fredericton, New Brunswick
# False
# E3A1X5
# 24 Thompson Avenue, St. Stephen, New Brunswick
# False
# E3L2M1
# 51 Main Street, St. Stephen, New Brunswick
# False
# E3L1Z5
# 167 Todd's Point Road, Dufferin, New Brunswick
# False
# E3L3R6
# Rrichardson Road, Deer Island, New Brunswick
# False
# E5V1J2
# 3888 Rte 620 Tay Creek, Greater Estey's Bridge, New Brunswick
# False
# E3G6K8
# 100 Winterport Way, Fredericton, New Brunswick
# False
# E3A1X5
# 2511 Route 774, Campobello Island, New Brunswick
# False
# E5E1L7
# 98-17 Ross Point Road, Greater Saint Andrews, New Brunswick
# False
# E5B3G5
# - Salt Marsh Road, Saint Andrews, New Brunswick
# False
# E5B1R9
# 4973 Route 112, Greater Salisbury, New Brunswick
# False
# E4Z5T5
# 98-17 Ross Point Road, Greater Saint Andrews, New Brunswick
# False
# E5B3G5
# - Salt Marsh Road, Saint Andrews, New Brunswick
# False
# E5B1R9
# 4973 Route 112, Greater Salisbury, New Brunswick
# False
# E4Z5T5
# 9 Bromfield, Moncton, New Brunswick, E1G0N7
# False
# E1G0N7
# 25 Gilman Lane, St. Stephen, New Brunswick
# False
# E3L4J3
# 15-3 Winterport Way, Fredericton, New Brunswick
# False
# E3A1X5
# 62 Patricia, Riverview, New Brunswick, E1B5C8
# False
# E1B5C8
# 12 Lisgar Street, St. Stephen, New Brunswick
# False
# E3L2T4
# - Leavitt Head Road, Greater St. George, New Brunswick
# False
# E5C3E6
# 63 Jack Road, Pennfield, New Brunswick
# False
# E5H1X2
# 20 Route 960, Cape Tormentine, NB, Cape Tormentine, New Brunswick
# False
# E4M2C6
# - Route 750, Dennis-Weston, New Brunswick
# True
# 46 Main Street A, St. Stephen, New Brunswick
# False
# E3L1Z5
# 60 Mill Road, St.Stephen, New Brunswick
# False
# E3L1K4
# LOT Rte 117, Escuminac, New Brunswick
# True
# 1054 rue Centrale, Memramcook, New Brunswick
# False
# E4K3T6
# 1102 NB RTE 890, Newtown, New Brunswick
# False
# E4G1M2
# 88-6 Oceanview Lane, Upper Cape, NB, Upper Cape, New Brunswick
# False
# E4M2T8
# Ghost Rd, Saint Andrews, New Brunswick
# False
# E5B2T2
# 30 Telly Road, Miramichi, New Brunswick
# False
# E1V4R9
# 98-7 Ross Point Road, Greater Saint Andrews, New Brunswick
# False
# E5B3G5
# 60 Champion, Dieppe, New Brunswick, E1A9E8
# False
# E1A9E8
# 2100 Bridletowne Cir, Clarks Corners, New Brunswick
# True
# 56 Satinwood, Pointe-du-Chene, New Brunswick
# False
# E4P5B7
# 15-5 Winterport Way, Fredericton, New Brunswick
# False
# E3A1X5
# 81 Harbour View Lane, Greater Saint Andrews, New Brunswick
# False
# E5B3G8
# 458 Luciphy Road, Jolicure, NB, Pointe de Bute, New Brunswick
# False
# E4L4S6
# 22 Porter Street, St. Stephen, New Brunswick
# False
# E3L2M7
# 28 Abbott Street, St. Stephen, New Brunswick
# False
# E3L3C4
# 10887 Route 430, Trout Brook, New Brunswick
# False
# E9E1P8
# 30 Cranberry Lane, Noonan, New Brunswick
# False
# E3A0H3
# 184 Route 176, Pennfield, New Brunswick
# False
# E5H1T9
# - Lakeshore Drive North, Bethel, New Brunswick
# False
# E5C1N0
# 156 Tower Hill Road, Saint Stephen, New Brunswick
# False
# E5A2P9
# 1166 Mascarene Road, Greater St. George, New Brunswick
# False
# E5C3E6
# 85-66 & 85-70 Maple Leaf Crt, Campobello Island, New Brunswick
# False
# E5E1Z4
# Old Saint John Road, St. George, New Brunswick
# False
# E2M2B3
# 29 Mountain Side, Deer Island, New Brunswick
# False
# E5V1G3
# Haute Aboujagane Land, Haute Aboujagane, New Brunswick
# False
# E4P5M8
# 07- 5 Route 960, Cape Spear, NB, Cape Spear, New Brunswick
# False
# E4M0A3
# Lot B Vacant Land Rte 170, Oak Bay, New Brunswick
# True
# 12 Acre Lot, Rte 117, Baie Ste. Anne, New Brunswick
# True
# 50 Assomption, Moncton, New Brunswick, E1C0C5
# False
# E1C0C5
# - Lynnfield Road, Lynnfield, New Brunswick
# False
# E5A1V9
# 10 Murray Lane, Oak Bay, New Brunswick
# False
# E3L4H9
# - Paradox Point, Bocabec, New Brunswick
# False
# E5B3Y1
# - Upper Waweig Road, Waweig, New Brunswick
# False
# E3L4N1
# 20 Board Road Extension, Oak Bay, New Brunswick
# False
# E3L4K4
# 62 Irene - Spring 2020, Shediac, New Brunswick, E4P0S4
# False
# E4P0S4
# Colpitts Road, Colpitts Settlement, New Brunswick
# False
# E4J3G4
# Colpitts Road, Colpitts Settlement, New Brunswick
# False
# E4J3G4
# 637 Route 170 Route, Oak Bay, New Brunswick
# False
# E3L4C3
# Manhurst Cross Road - Lot 1, Sussex, New Brunswick
# False
# E4G1G6
# 32 King Street, St. Stephen, New Brunswick
# False
# E3L2Y6
# Lot 01-2 Rte 117, Hardwicke Road, Black River - Hardwicke, New Brunswick
# False
# E9A1K2
# Lot # 85-139, Campobello Island, New Brunswick
# False
# E5E1X2
# 79 Moody's Shore Road, Bass River, New Brunswick
# False
# E4T1C7
# Shore Lot 3+3A Baron Lane, Dufferin, New Brunswick
# False
# E3L3R7
# 4639 Route 114, Shepody, New Brunswick
# False
# E4H4J8
# Gum Road, Miramichi, New Brunswick
# False
# E1V7H1
# 5 Birchwood Court, St. Stephen, New Brunswick
# False
# E3L2V2
# Camp and Land, Centre Village, NB, Greater Sackville, New Brunswick
# True
# 13 Ledgewood Drive, Crocker Hill, New Brunswick
# False
# E3L3Z7
# 98-3 Bayview Boulevard, Greater Saint Andrews, New Brunswick
# False
# E5B3G4
# 47 Queen Street East, St. Stephen, New Brunswick
# False
# E3L2J5
# Lot 89-2, Route 445, Fair Isle, New Brunswick
# False
# E9G2M7
# 360 Colpitts Road, Colpitts Settlement, New Brunswick
# False
# E4J1B6
# 98-2 Bayview Boulevard, Greater Saint Andrews, New Brunswick
# False
# E5B3G4
# Vacant Lot, Route 960, Cape Spear, NB, Cape Spear, New Brunswick
# False
# E4M3W9
# Lot Union Street, St. Stephen, New Brunswick
# False
# E3L1T2
# Route 885 - Lot, Greater Salisbury, New Brunswick
# False
# E4J1T6
# 98-1 Bayview Boulevard, Greater Saint Andrews, New Brunswick
# False
# E5B3G4
# 274 Milltown Boulevard, St. Stephen, New Brunswick
# False
# E3L1H6
# 208 Upper Mills Road, Greater Saint Stephen, New Brunswick
# False
# E3L3E8
# 415 Beckwith Road, Greater Salisbury, New Brunswick
# False
# E4Z3J3
# 65 North Road, Campobello Island, New Brunswick
# False
# E5E1A1
# 876 Route 172, Greater St. George, New Brunswick
# False
# E5C3E6
# 29 Flint Court, Moncton, New Brunswick
# False
# E1G2H3
# 51 ALEX JACK DETOUR Road, Utopia, New Brunswick
# False
# E5C2G4
# 21 Whispering Pines Lane, Crocker Hill, New Brunswick
# False
# E3L0A1
# Murray Road Bartletts Mills, St. Andrews, New Brunswick
# False
# E5B2Y8
# 16 tower Road, Cape Tormentine, NB, Cape Tormentine, New Brunswick
# False
# E4M0C4
# Manhurst Cross Road - Lot 2, Greater Havelock, New Brunswick
# False
# E4Z5S8
# LOT 2006-4 Carl Avenue, Greater Kingsclear, New Brunswick
# False
# E6K2W9
# Knightville Road, Knightville, New Brunswick
# False
# E4G1E7
# 4 Mcadam Court, St. Stephen, New Brunswick
# False
# E3L3G6
# 63 Balsam Ave, Noonan, New Brunswick
# False
# E3A0J8
# Deer Island Point  Route 772, Deer Island, New Brunswick
# False
# E5V1G5
# 106  Fraser Street, St. Stephen, New Brunswick
# False
# E2L4J7
# - Bar Road, Saint Andrews, New Brunswick
# False
# E5B2Y7
# 124 Queen Street West, St. Stephen, New Brunswick
# False
# E3L2L2
# Lot 15-2 Winterport Way, Fredericton, New Brunswick
# True
# 254 Ledge Road, Crocker Hill, New Brunswick
# False
# E3L3Z3
# 20 Cape Spear Cross Road, Cape Spear, NB, Cape Spear, New Brunswick
# False
# E4M1E8
# 15 Will Blakney Road, Greater Salisbury, New Brunswick
# False
# E4J3K7
# 15 Pyne, Miramichi, New Brunswick
# False
# E1N2X7
# Lot 6 Upper Durham Road, Upper Durham, New Brunswick
# False
# E6C1B3
# Lot Upper Mills Road, Greater Saint Stephen, New Brunswick
# False
# E7L5X7
# Old Saint John Road, Lepreau, New Brunswick
# False
# E5J1M5
# 991 Portage Vale Road, Portage Vale, New Brunswick
# False
# E4Z3E4
# Land Paradox Point, Bocabec, New Brunswick
# False
# E5B3Y1
# Lot 01-3, Rte 117, Black River - Hardwicke, New Brunswick
# False
# E9A1L7
# 127 King Street, St. Stephen, New Brunswick
# False
# E3L2H9
# 601 Anagance Ridge Road, Greater Havelock, New Brunswick
# False
# E4Z2T7
# 98-16 Ross Point Road, Greater Saint Andrews, New Brunswick
# False
# E5B3G6
# 1449 Amirault, Dieppe, New Brunswick, E1A4T4
# False
# E1A4T4
# 130 Paradox Point, Bocabec, New Brunswick
# False
# E5B3X1
# 512 Canada Street, Fredericton, New Brunswick, E3A  4A7
# False
# E3A4A7
# 10 McLaren Dr, Saint Andrews, New Brunswick
# False
# E5B3E3
# 40 Jessica, Fredericton, New Brunswick
# False
# E3A6T7
# 3771 Route 535, Cocagne, New Brunswick
# False
# E4R3E7
# 2  Scovil Street, Deer Island, New Brunswick
# False
# E5V1V8
# 238 Ledge Road, St. Stephen, New Brunswick
# False
# E3L3Z4
# Land Bunker Hill Road, Campobello Island, New Brunswick
# False
# E5E1M3
# 68 Acres Welfield Road, Miramichi, New Brunswick
# True
# Deer Island Point Road, Deer Island, New Brunswick
# False
# E5V1T4
# 547 Main, Blacks Harbour, New Brunswick, E5H1B9
# False
# E5H1B9
# 98-14 Bayview Boulevard, Greater Saint Andrews, New Brunswick
# False
# E5B3G6
# 98-13 Ross Point Road, Greater Saint Andrews, New Brunswick
# False
# E5B3G5
# 966 Bourque road, Dieppe, New Brunswick, E1A7L3
# False
# E1A7L3
# 118 Route 735, Western Charlotte, New Brunswick
# True
# 7453 Route 3, Baille, New Brunswick
# True
# Vacant Land Chamcook NB, Saint Andrews, New Brunswick
# True
# 126 King Street, Saint Andrews, New Brunswick
# False
# E5B1Y6
# 131 Old School House Road, Birneys Lake, New Brunswick
# True
# - Rollingdam Road, Saint Stephen, New Brunswick
# False
# E5A1B2
# 182 Union Street, St. Stephen, New Brunswick
# False
# E3L1W1
# 182 Union Street, St. Stephen, New Brunswick
# False
# E3L1W1
# Lot 89-1 Route 445, Fair Isle, New Brunswick
# False
# E9G2M7
# Lot 15-1 Winterport Way, Fredericton, New Brunswick
# False
# E3A1X5
# 50 Queen Street East, St. Stephen, New Brunswick
# False
# E3L2J6
# Lot #28 Streamfront, Piskahegan, New Brunswick
# True
# 85 Lakeshore Drive, Bethel, New Brunswick
# False
# E5C1N0
# 100 acres Route 735, Western Charlotte, New Brunswick
# True
# Lot 89-4 Route 445, Fair Isle, New Brunswick
# False
# E9G2M7
# Lot Route 530, Grande Digue, New Brunswick
# True
# 2852 Route 117, Kouchibouguac, New Brunswick
# False
# E4X2P2
# Vacant Lot #2 Rankine Road, Bayside, New Brunswick
# False
# E5B2V2
# 46 Main Street B, St. Stephen, New Brunswick
# False
# E3L1Z5
# 64 Henderson Street, Miramichi, New Brunswick
# False
# E1N2R5
# 7888 Route 112 Hunters home, Greater Salisbury, New Brunswick
# False
# E4Z3H7
# 423 Route 725, Dennis-Weston, New Brunswick
# False
# E3L4V9
# 1431 Route 755, St. Stephen, New Brunswick
# False
# E5A2P8
# 1886 Route 515, Bouctouche, New Brunswick
# False
# E4S0B3
# 124 Chamcook Lake #1 Road, Chamcook, New Brunswick
# False
# E5B3C3
# 98-15 Bayview Boulevard, Greater Saint Andrews, New Brunswick
# False
# E5B3G6
# LOT # 2 Oaksway Street, St. Stephen, New Brunswick
# False
# E3L1P8
# Route 170, St. Stephen, New Brunswick
# True
# 2.74 Acres Hopps Lane, Oak Haven, New Brunswick
# False
# E3L3V3
# 10 Downey Lane, Dennis-Weston, New Brunswick
# False
# E3L4V9
# - Route  725, Western Charlotte, New Brunswick
# True
# 60 Route 735, Western Charlotte, New Brunswick
# True
# 10 Downey Lane, Dennis-Weston, New Brunswick
# False
# E3L4V9
# - Route  725, Western Charlotte, New Brunswick
# True
# 60 Route 735, Western Charlotte, New Brunswick
# True
# 40 Queen Street West, St Stephen, St. Stephen, New Brunswick, E3L2K3
# False
# E3L2K3
# 11 Pagan Street, St. Stephen, New Brunswick
# False
# E3L1R9
# 62 Duffy Rd., Riverview, New Brunswick
# False
# E1J1A9
# 98-12 Ross Point Road, Greater Saint Andrews, New Brunswick
# False
# E5B3G5
# 1046-1048 North Road, Campobello Island, New Brunswick
# False
# E5E1E5
# - Glass Shore Road, Bocabec, New Brunswick
# False
# E5B3X1
# 27 Fraser, Oak Bay, New Brunswick
# False
# E3L4B5
# Waterfront Acreage on Braveheart Road, Renous - Quarryville, New Brunswick
# False
# E9B0A4
# 50 acres Splan Pond Area Route, Dennis-Weston, New Brunswick
# False
# E3L5G7
# 7878 Hunters Home, Havelock, New Brunswick
# False
# E4C3J6
# Lot 4741 Rte 117, Upper Miramichi, New Brunswick
# False
# E1N5L7
# 258 Royree Road, Western Charlotte, New Brunswick
# True
# 98-11 Ross Point Road, Greater Saint Andrews, New Brunswick
# False
# E5B3G5
# 213 Maces Bay Road, Maces Bay, New Brunswick
# False
# E5J1S6
# 14 Gowan Loop Rd, Saint Andrews, New Brunswick
# False
# E5B3K3
# 550 Cookville Road, Greater Sackville, New Brunswick
# False
# E4L2A7
# 3 Newport DR, Moncton, New Brunswick, E1G2L9
# False
# E1G2L9
# Lot 3 Motivation Avenue, Quispamsis, New Brunswick, E2G2A1
# False
# E2G2A1
# 3 Gabriel Street, Edmundston, New Brunswick
# False
# E7B1S5
# 110 Route 1148, Tracey Mills, New Brunswick
# False
# E7K2C2
# 125 Cocagne Sud, Cocagne, New Brunswick, E4R2J8
# False
# E4R2J8
# 44 Hamilton RD, Elgin, New Brunswick, E4Z1V8
# False
# E4Z1V8
# 1012 Route 820, Barnesville, New Brunswick
# False
# E5N3K9
# 65 Curry, Moncton, New Brunswick, E1A3V6
# False
# E1A3V6
# 41 Desrosiers, Dieppe, New Brunswick, E1A7W5
# False
# E1A7W5
# 17 Anchorage Avenue, Millidgeville, New Brunswick
# False
# E2K5R1
# 1346 Four Road, Inkerman, New Brunswick
# True
# 56 Pincher Street, Greater Woodstock, New Brunswick
# False
# E7M5H1
# 13 des Erables RD, Dieppe, New Brunswick, E1A8X7
# False
# E1A8X7
# 34 Louise Court, Fredericton, New Brunswick, E3G5M5
# False
# E3G5M5
# 43 Larochelle, Dieppe, New Brunswick, E1A9B6
# False
# E1A9B6
# 66 Martindale DR, Moncton, New Brunswick, E1G2J3
# False
# E1G2J3
# - des Patriotes Street, Caraquet, New Brunswick, E1W1A7
# False
# E1W1A7
# 225 SERENITY Lane Unit 325, Fredericton, New Brunswick, E3B0H1
# False
# E3B0H1
# Lot 14-6 & 14-7 Burtis Way, Cumberland Bay, New Brunswick
# False
# E4A0B8
# 365 Gibson Street, Fredericton, New Brunswick, E3A4E7
# False
# E3A4E7
# Lot#78 Apple Blossom Trail, Hampton, New Brunswick, E5N0J6
# False
# E5N0J6
# 60 Carrie Street, Rusagonis - Waasis, New Brunswick
# False
# E3B8W3
# 20 Sedona CRES, Moncton, New Brunswick, E1G5X6
# False
# E1G5X6
# 102 Central Avenue, Island View Heights, New Brunswick
# False
# E2M4C7
# 131 Lawrence Long Road, Acamac, New Brunswick
# False
# E2M6A2
# 35 Walker Crescent, Hampton, New Brunswick, E5N5Z7
# False
# E5N5Z7
# 397 Parkhurst Drive, Fredericton, New Brunswick, E3B2K2
# False
# E3B2K2
# Vacant Lot 3 Route, Brockway, New Brunswick
# False
# E6K2B6
# - North Road, Campobello Island, New Brunswick
# False
# E5E1E5
# - Diggle Drive, Quispamsis, New Brunswick, E2E3T4
# False
# E2E3T4
# 378 BROAD Road, Geary, New Brunswick
# False
# E2V3P6
# 635 3ime ave Avenue, Grand Sault/Grand Falls, New Brunswick
# True
# 29 Sheffield Court, Fredericton, New Brunswick, E3B4M9
# False
# E3B4M9
# 64 Madonna Drive, Greater Kingsclear, New Brunswick
# False
# E3E2N1
# 20 Acadie Siding, Acadie Siding, New Brunswick
# False
# E4Y1R6
# 44 Shore Road, Maquapit Lake, New Brunswick
# False
# E4B4A7
# 78 Point Park DR, Riverview, New Brunswick, E1B1C5
# False
# E1B1C5
# Lot 76-2 Renaud, Saint - Antoine, New Brunswick
# True
# 180 Murielle CRES, Dieppe, New Brunswick, E1A8J1
# False
# E1A8J1
# 186 Lincoln Road, Fredericton, New Brunswick, E3B2A3
# False
# E3B2A3
# 83 ch Rang 5, Saint-Basile, New Brunswick
# False
# E7C2B3
# Lot Melanie Street, Grand Falls - Grand-Sault, New Brunswick
# True
# 105 Route 2950, Bear Island, New Brunswick
# False
# E6L1H5
# Lot Route 945, Haute Aboujagane, New Brunswick, E4P5T3
# False
# E4P5T3
# 323 Irving BLVD, Bouctouche, New Brunswick, E4S3K8
# False
# E4S3K8
# 1259 Route 425, Whitney, New Brunswick
# False
# E1V4K6
# 122 Cunard, Richibucto, New Brunswick, E4W3Z4
# False
# E4W3Z4
# 24 Alderwood Street, Island View Heights, New Brunswick
# False
# E2M5X4
# 182 Chartersville RD, Dieppe, New Brunswick, E1A1K4
# False
# E1A1K4
# 5398 Route 105, Whites Cove, New Brunswick
# False
# E4C3H6
# 3624 Route 530, Grande Digue, New Brunswick
# True
# 582 Chartersville, Dieppe, New Brunswick, E1A1K6
# False
# E1A1K6
# 90 Westminster Court, Millidgeville, New Brunswick
# False
# E2K4S3
# 138 Britain Street, Saint John Centre, New Brunswick
# False
# E2L1X5
# 10 & 14 107 Route, Nashwaak Bridge, New Brunswick
# False
# E6C2G7
# 111 Janice, Moncton, New Brunswick, E1A0C5
# False
# E1A0C5
# 63 Nightingale Lane, Quispamsis, New Brunswick, E2E3T1
# False
# E2E3T1
# 101 Leinster Street, Saint John Centre, New Brunswick
# False
# E2L1J4
# 516 Riverside Drive Unit 4, Fredericton, New Brunswick, E3A8C2
# False
# E3A8C2
# 333 Elmore CRT, Riverview, New Brunswick, E1B2L3
# False
# E1B2L3
# 2 Lindsay Lane, St. Stephen, New Brunswick, E3L0B2
# False
# E3L0B2
# LOT 11 Headland Road, Kingsclear, New Brunswick, E2E0E5
# False
# E2E0E5
# 186 Williston Drive, Miramichi, New Brunswick, E1V5W9
# False
# E1V5W9
# 972 St-François Street, Edmundston, New Brunswick, E3V4R2
# False
# E3V4R2
# 546 Emblem Court, Oromocto, New Brunswick, E2V1H7
# False
# E2V1H7
# 217 McClellan, Riverview, New Brunswick, E1B1X3
# False
# E1B1X3
# 155 Lian Street Unit 436, Fredericton, New Brunswick, E3C0L9
# False
# E3C0L9
# 3 Wallace CRT, Riverview, New Brunswick, E1B3V2
# False
# E1B3V2
# Lot A Wilsey Road, Rusagonis - Waasis, New Brunswick
# False
# E3B9A5
# 63 Thorncastle ST, Lutes Mountain, New Brunswick, E1G0S6
# False
# E1G0S6
# Lot 4 Motivation Avenue, Quispamsis, New Brunswick, E2G2A1
# False
# E2G2A1
# Lot 04-20 Wayne ST, Shediac, New Brunswick, E4P2W8
# False
# E4P2W8
# 72 Watters Drive, Fredericton, New Brunswick, E3A3T2
# False
# E3A3T2
# 920 Coverdale RD, Riverview, New Brunswick, E1B5E5
# False
# E1B5E5
# 831 Dever Road, Greendale, New Brunswick
# False
# E2M4L2
# 69 Acadie, Bouctouche, New Brunswick, E4S2T7
# False
# E4S2T7
# 1087 Route 850, Kiersteadville, New Brunswick
# False
# E5T3P3
# 313 Lavoie, Dieppe, New Brunswick, E1A6R8
# False
# E1A6R8
# 160 Nevers Road, Nevers Road, New Brunswick
# True
# 129 Todd Street, Glen Falls - Golden Grove, New Brunswick
# False
# E2H1Y6
# 148 Route 825, Killarney Road, New Brunswick
# False
# E3G9G1
# 10 Route 601, Richibucto Road, New Brunswick
# False
# E3A7E1
# 113 Slipp Street, Woodstock, New Brunswick, E7M2R5
# False
# E7M2R5
# 102 Horton Road, Rothesay, New Brunswick, E2H1P8
# False
# E2H1P8
# Lot Route 390, Greater Perth - Andover, New Brunswick
# True
# 282 Price Road, Drummond, New Brunswick
# False
# E3Y2N7
# 26 Birchwood Place, Island View Heights, New Brunswick
# False
# E2M5G5
# 18 Islands, Greater Canterbury, New Brunswick
# True
# 234 Edinburgh Street, Fredericton, New Brunswick, E3B2C9
# False
# E3B2C9
# 118 St John ST, Pointe-du-Chene, New Brunswick
# False
# E4P5G5
# 484 Bon Secours RD, St. Paul, New Brunswick
# False
# E4T3B4
# 560 Route 2896, Williamstown, New Brunswick
# False
# E7K1S8
# 2170 Route 885, Havelock, New Brunswick, E4Z5N5
# False
# E4Z5N5
# LOT 12-2 Hope RD, Steeves Mountain, New Brunswick, E1G3Z1
# False
# E1G3Z1
# 50 Brigadoon Terrace, Rockwood Park, New Brunswick
# True
# 27 Saint Paul's Street, Hampton, New Brunswick, E5N5P8
# False
# E5N5P8
# 03-11 Archangel Way, Keswick Ridge, New Brunswick, E6L0A5
# False
# E6L0A5
# 124 Valmont CRES, Dieppe, New Brunswick, E1A1N2
# False
# E1A1N2
# Vacant Lot 17-1 John Chessie Road, Hanwell, New Brunswick
# False
# E6K2Z8
# Lot Elm Street, Chipman, New Brunswick, E4A1X6
# False
# E4A1X6
# 8 Collett Court, Fredericton, New Brunswick, E3A4G2
# False
# E3A4G2
# 1303 Brittain Road, Lower Greenwich, New Brunswick
# False
# E5K4K1
# 97 Carleton Street, Saint John Centre, New Brunswick
# False
# E2L2Z2
# 19 BARKER Street, Oromocto, New Brunswick, E2V2K4
# False
# E2V2K4
# 58 Whisperwood, Moncton, New Brunswick, E1G0P8
# False
# E1G0P8
# Lot Dooley Road, Johnville, New Brunswick
# False
# E7J1Y1
# 121-127 Wright Street, Indiantown, New Brunswick
# False
# E2K3Z5
# 16 Hillcrest Avenue, Hartland, New Brunswick, E7P1M6
# False
# E7P1M6
# 21-23 Mansfield ST, Moncton, New Brunswick, E1A2V8
# False
# E1A2V8
# 19 Stewart Street, Fredericton, New Brunswick, E3G3V4
# False
# E3G3V4
# 127 Monash Cove, Upper Cape, New Brunswick
# False
# E4M2R7
# 11768 Route 105, Kilburn, New Brunswick
# False
# E7H3X3
# 294 Thomas, Dieppe, New Brunswick, E1A2C2
# False
# E1A2C2
# 9 Bristol CRES, Riverview, New Brunswick, E1B0S9
# False
# E1B0S9
# Lot 19-2 South Shediac River RD, Shediac Bridge - Shediac River, New Brunswick
# False
# E4R1N5
# 582 Bonita Avenue, Silver Falls, New Brunswick
# False
# E2G2T3
# 19 Orchard Lane, Greater Kingsclear, New Brunswick
# False
# E3C0E2
# Lot 2018-3 Grand Pass Court, Greater Estey's Bridge, New Brunswick
# False
# E6L1B6
# 129 Todd Street, Glen Falls - Golden Grove, New Brunswick
# False
# E2H1Y6
# 6683 Route 105, Sussex, New Brunswick, E4E2C2
# False
# E4E2C2
# 55 Maxwell Drive, Sussex, New Brunswick, E4E2E1
# False
# E4E2E1
# 1521 Tobique Road, Drummond, New Brunswick, E3Y2P8
# False
# E3Y2P8
# Lot du Portage, Caraquet, New Brunswick, E1W1A8
# False
# E1W1A8
# - North Road, Campobello Island, New Brunswick
# False
# E5E1E5
# 28 32e Avenue, Edmundston, New Brunswick, E3V2S2
# False
# E3V2S2
# 95 Blanchard Court, Fredericton, New Brunswick, E3G3X2
# False
# E3G3X2
# 1001 Bossé Road, Saint-Joseph-De-Madawaska, New Brunswick
# False
# E7B2K2
# 116 Falaise, Grande-Anse, New Brunswick
# True
# Lot 3 Motivation Avenue, Quispamsis, New Brunswick, E2G2A1
# False
# E2G2A1
# Vacant Lot 17-1 John Chessie Road, Hanwell, New Brunswick
# False
# E6K2Z8
# 83 ch Rang 5, Saint-Basile, New Brunswick
# False
# E7C2B3
# Lot 2018-4 Grand Pass Court, Greater Estey's Bridge, New Brunswick
# False
# E6L1B6
# 44 Shore Road, Maquapit Lake, New Brunswick
# False
# E4B4A7
# 3 Hope RD 12, Steeves Mountain, New Brunswick, E1G3Z1
# False
# E1G3Z1
# 63 Indian Lake Road, Lakeville Corner, New Brunswick
# False
# E4B1L9
# 195 Pleasant ST, Moncton, New Brunswick, E1A2V6
# False
# E1A2V6
# 4064 Route 480, Acadieville, New Brunswick
# False
# E4Y2B8
# 8 Collett Court, Fredericton, New Brunswick, E3A4G2
# False
# E3A4G2
# 2343 Route 490, Ammon, New Brunswick, E1G4R6
# False
# E1G4R6
# 639 Cormier Village RD, Cormier - Village, New Brunswick
# False
# E4P5W2
# 160 Nevers Road, Nevers Road, New Brunswick
# True
# 43 Larochelle, Dieppe, New Brunswick, E1A9B6
# False
# E1A9B6
# 32 Derby ST, Moncton, New Brunswick, E1C6Y5
# False
# E1C6Y5
# 1346 Four Road, Inkerman, New Brunswick
# True
# 9 Bristol CRES, Riverview, New Brunswick, E1B0S9
# False
# E1B0S9
# 19 First AVE, Pointe-du-Chene, New Brunswick
# False
# E4P4E8
# 20 Shallon Lane, Fredericton, New Brunswick
# False
# E3A9R4
# 284 Carriage Hill Road, Hanwell, New Brunswick
# True
# 27 Grandview Lane, Grand Lake, New Brunswick
# True
# 1686 Route 310, Coteau Road, New Brunswick, E8T3K3
# True
# 79-81 Algonquin, Moncton, New Brunswick, E1G2C8
# True
# 861 Red Head Road, Red Head, New Brunswick
# True
# 76 Ashfield Drive, Quispamsis, New Brunswick, E2G1R2
# True
# Lot 19-01 Bayview Drive, Saint Andrews, New Brunswick
# True
# 19 Ouellette Lane, Greater Drummond, New Brunswick
# True
# 11 Westfield Place, Fredericton, New Brunswick, E3G0C1
# True
# Lot Route 955, Murray Corner, New Brunswick, E4M3M2
# True
# 4 Acacia Court, Fredericton, New Brunswick, E3B1Y7
# True
# 23 Willowdale Drive, Rusagonis - Waasis, New Brunswick
# True
# 36 Crandall ST, Moncton, New Brunswick, E1C4C5
# True
# Lot 13 Motivation Avenue, Quispamsis, New Brunswick, E2G2A1
# True
# 385 Duke Street, Bayshore, New Brunswick
# True
# 828 Murray RD, Saint - Antoine, New Brunswick
# True
# 90 Principale, Memramcook, New Brunswick, E4K1A6
# True
# 31 School ST, Rexton, New Brunswick, E4W2E4
# True
# 56 Cameron Drive, Burton, New Brunswick
# True
# Lot 10 Motivation Avenue, Quispamsis, New Brunswick, E2G2A1
# True
# 19 First AVE, Pointe-du-Chene, New Brunswick
# True
# Lot 76-3 Renaud, Saint-Antoine, New Brunswick
# True
# 690 Route 1120, Maquapit Lake, New Brunswick
# True
# 555 Principale, Pointe-Verte, New Brunswick
# True
# 1644 Wilsey Road, Rusagonis-Waasis, New Brunswick
# True
# 25 Norwood AVE, Moncton, New Brunswick, E1C6L8
# True
# / Goodspeed Road, Penniac, New Brunswick
# True
# 30 Shornecliff Drive, Quispamsis, New Brunswick, E2E0G9
# True
# 65 KEYHOLE Road, Grand Lake, New Brunswick
# True
# 89 Hannington, Shediac Cape, New Brunswick, E4P3C8
# True
# 250 Whittaker Road, Rusagonis - Waasis, New Brunswick
# True
# 77 Houlahan ST, Dieppe, New Brunswick, E1A0S9
# True
# 155 Lian Street Unit 325, Fredericton, New Brunswick, E3C0L9
# True
# 767 Old Shepody Road, Hammondvale, New Brunswick
# True
# 650 Principale, Petit - Rocher, New Brunswick
# True
# 32 Derby ST, Moncton, New Brunswick, E1C6Y5
# True
# 35 Sagewood CRES, Moncton, New Brunswick, E1G1Z4
# True
# 506 Upper Goshen Road, Elgin, New Brunswick, E4Z0C4
# True
# 681 Rogers Road, Long Point, New Brunswick
# True
# 338 Sunset, Beresford, New Brunswick, E2A2G6
# True
# 136 Strong Street, Woodstock, New Brunswick, E7M2V9
# True
# 680 Front Mountain RD, Moncton, New Brunswick, E1G3H3
# True
# 4064 Route 480, Acadieville, New Brunswick
# True
# Lot#6 Apple Blossom Trail, Hampton, New Brunswick, E5N0J6
# True
# 97 Gondola Point Road, Rothesay, New Brunswick, E2E2H6
# True
# 150 Alma ST Unit 1, Moncton, New Brunswick, E1C4Y7
# True
# 38 Loyalist Drive, Hampton, New Brunswick, E5N5V6
# True
# 44 Squire Drive, Quispamsis, New Brunswick, E2G1C1
# True
# 52 Flagstone Drive, Quispamsis, New Brunswick, E2G0B8
# True
# 641 Salisbury Back RD, Colpitts Settlement, New Brunswick
# True
# 20 Heathfield CRT, Moncton, New Brunswick, E1A0J1
# True
# 62 Waverley, Moncton, New Brunswick, E1C7T7
# True
# 32 Fourth AVE, Pointe-du-Chene, New Brunswick
# True
# Lot 91-3 Hutchinson LANE, Rexton, New Brunswick, E4W1Y8
# True
# 81 McNair Drive, Nackawic, New Brunswick, E6G1A5
# True
# 5 Andrew Court, Grand Bay - Westfield, New Brunswick
# True
# 3 Craig CRT, Riverview, New Brunswick, E1B4M4
# True
# 71 Pointe des Robichaud, Val - Comeau, New Brunswick
# True
# 1498 Champlain ST, Dieppe, New Brunswick, E1A1R4
# True
# 615 Weisner RD, Lakeville, New Brunswick, E1H1T6
# True
# 10 Route 1435, Noonan, New Brunswick, E3A7H6
# True
# 8 Kingsley Avenue, Quispamsis, New Brunswick, E2E4Z1
# True
# 16 De La Barronie, Grand Barachois, New Brunswick
# True
# 185 McAuley Road, Smiths Creek, New Brunswick
# True
# Lot 2019-2 3 Route 2, Brockway, New Brunswick
# True
# 69 Irène Street, Edmundston, New Brunswick, E3V1B8
# True
# 5 Hope RD 12, Steeves Mountain, New Brunswick, E1G3Z1
# True
# 239 Driftwood Loop, Fredericton, New Brunswick, E3B7P1
# True
# 745 Bridge Street, Bathurst, New Brunswick, E2A1W9
# True
# 225 Serenity Lane Unit 102, Fredericton, New Brunswick, E3B0H1
# True
# 207 Williams Street, Grand Falls-Grand-Sault, New Brunswick
# True
# 20 Burlington Court, Pokiok, New Brunswick
# True
# Lot 8 Motivation Avenue, Quispamsis, New Brunswick, E2G2A1
# True
# 701 Pleasant Vale Road, Elgin, New Brunswick, E2Z0E1
# True
# 149 Gagnon, Moncton, New Brunswick, E1A0Z4
# True
# 549 Saint Olivier, Canisto Road, New Brunswick
# True
# 9 Greystone Drive, Quispamsis, New Brunswick, E2G0J1
# True
# 105 Route 5609, Mill Cove, New Brunswick
# True
# 102 Route 1303, Upper Gagetown, New Brunswick, E5M1N2
# True
# 4 Summer Point LANE, Baie - Verte, New Brunswick
# True
# 13 Evergreen DR, Shediac, New Brunswick, E4P1R9
# True
# 15 Clarendon DR, Moncton, New Brunswick, E1G0M8
# True
# 154 Frenette, Beresford, New Brunswick, E8K1Y5
# True
# - Connors Lane, Bloomfield, New Brunswick
# True
# 17 Leeswood Drive, Quispamsis, New Brunswick, E2G1N1
# True
# Lot 2016-2 Grand Pass Court, Greater Estey's Bridge, New Brunswick
# True
# 4392 Heritage Drive, Tracy, New Brunswick, E5L1B9
# True
# 7 IAN Street, Champlain Heights, New Brunswick
# True
# 11 Coronation Court, Oromocto, New Brunswick, E2V2M9
# True
# 1 Princess Street, Saint John Centre, New Brunswick
# True
# 8 Rockport, Riverview, New Brunswick, E1B5L5
# True
# Lot Hillandale Drive, Grand Bay-Westfield, New Brunswick
# True
# 176 Sherwood Road, Greater Woodstock, New Brunswick
# True
# 532 Couturier Road, Saint-Joseph, New Brunswick
# True
# 1793 Nicholas Denys, Nicholas - Denys, New Brunswick
# True
# 215 Milltown Boulevard, St. Stephen, New Brunswick, E3L1G7
# True
# 44-46 Williams ST, Moncton, New Brunswick, E1C2G5
# True
# 65 Valmont, Dieppe, New Brunswick, E1A0H3
# True
# 642 Charters Settlement Road, Greater New Maryland, New Brunswick
# True
# 102 Sequoia DR, Moncton, New Brunswick, E1E4R8
# True
# 7 Elizabeth Ann Street, Burton, New Brunswick
# True
# 40 Aberdeen AVE, Riverview, New Brunswick, E1B3G1
# True
# 15 Forest Road, Rothesay, New Brunswick, E2H1B4
# True
# 72 Jenkins Drive, Quispamsis, New Brunswick, E2E0J4
# True
# Lot 95-3 Hillcrest Road, Forest Hills, New Brunswick
# True
# 20 Edgar Street, Inkerman Centre, New Brunswick
# True
# Lot 14 Motivation Avenue, Quispamsis, New Brunswick, E2G2A1
# True
# 2 Jones Avenue, Rothesay, New Brunswick, E2E1Y4
# True
# 141 Church Avenue, Sussex, New Brunswick, E4E1Z2
# True
# 108 Upper Stoneridge Road, Zealand, New Brunswick
# True
# 1189 Post Road, Sussex Corner, New Brunswick, E4E2X7
# True
# 2 Cross Road, Somerville, New Brunswick, E7P3B3
# True
# Lot#75 Apple Blossom Trail, Hampton, New Brunswick, E5N0J6
# True
# 3 Hope RD 12, Steeves Mountain, New Brunswick, E1G3Z1
# True
# Lot 2019-1 3 Route, Brockway, New Brunswick
# True
# 45 McAndrew ST, Moncton, New Brunswick, E1G4Z2
# True
# 985 Vanier, Bathurst, New Brunswick, E2A3N3
# True
# 490 Marguerite, Dieppe, New Brunswick, E1A7H1
# True
# 564 Pleasant Vale RD, Elgin, New Brunswick, E4Z2C7
# True

# %%
df.head(20)
# Out:
#                                               Address  Beds  Baths  \
# 0    10 Robin Dr, Fredericton, New Brunswick, E3C 1K6   5.0    2.0
# 1         03-2 Glebe Rd, Saint Andrews, New Brunswick   NaN    NaN
# 2   62 Parkin Street, Salisbury, New Brunswick, E4...   3.0    2.0
# 3          14 Murray Lane, St. Andrews, New Brunswick   4.0    2.0
# 4     140 Orleans St., Dieppe, New Brunswick, E1A 1W9   4.0    3.0
# 5   41 Eagle's Passage, Greater Saint Andrews, New...   3.0    3.0
# 6             7725 Rte 515, Saint-Paul, New Brunswick   2.0    1.0
# 7         133 Daigle Rd., Pointe-Sapin, New Brunswick   4.0    2.0
# 8   93 Principale, Memramcook, New Brunswick, E4K 1A7   5.0    4.0
# 9       294 Carleton St, Saint Andrews, New Brunswick   2.0    2.0
# 10  624 Royal Oaks Boulevard, Moncton, New Brunswi...   2.0    2.0
# 11       3574 Route 127, Saint Andrews, New Brunswick   NaN    NaN
# 12   517 Canal Rd, St. George, New Brunswick, E5C 1H6   3.0    2.0
# 13  13 Bulmer Lane, Sackville, NB, Sackville, New ...   3.0    1.0
# 14         175 Daigle Rd, Pointe-Sapin, New Brunswick   1.0    NaN
# 15  1 Baie Vista CRT, Shediac Cape, New Brunswick,...   3.0    2.0
# 16         5185 Route 127, St. Andrews, New Brunswick   4.0    2.0
# 17  30 Berkley Drive, Riverview, New Brunswick, E1...   4.0    3.0
# 18  Lot 07-02 Comeau Point Rd, Shemogue, New Bruns...   NaN    NaN
# 19       48 Augustus St, Saint Andrews, New Brunswick   3.0    2.0
#
#     House Size  Lot Size                             Type   Price Postal Code
# 0       1600.0     0.177              Residential          259900     E3C 1K6
# 1          NaN     1.140              Residential           11400      E5B2Z5
# 2       3790.0     0.850              Residential          549900     E4J 2N3
# 3       2200.0     1.150              Residential          449500         NaN
# 4       2808.0     0.124              Residential          236900     E1A 1W9
# 5       2160.0     1.000              Residential          794997      E5B0A9
# 6       1350.0     1.000              Residential           80000      E4T3R4
# 7       2168.0     0.990              Residential          169900      E9A1T7
# 8       5286.0     6.200              Residential          799900     E4K 1A7
# 9       1592.0     0.110              Residential          259000      E5B1P2
# 10      1232.0     0.134              Residential          264900     E1H 3S7
# 11         NaN    11.000              Residential          110000      E5B2W5
# 12      1560.0     3.800              Residential          298000     E5C 1H6
# 13      1214.0     0.400              Residential          134900     E4L 3R3
# 14       880.0     2.500              Residential           74900      E9A1T7
# 15      3440.0       NaN              Residential          475500     E4P 2Y7
# 16      1675.0     1.170              Residential          259000      E5B3A7
# 17      1735.0   869.000              Residential          239900     E1B 2L6
# 18         NaN     1.980              Residential           34900     E4N 3B4
# 19      1778.0     0.294              Residential          449000      E5B2E7

# %%
for index, address in tqdm(df['Address'].items(),total=len(df['Address'])):
    if address[-6] == 'E' and address[-5].isnumeric():
        df['Postal Code'][index] = address[-6:]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=720.0), HTML(value='')))
# /Users/renzoflores/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# count null values for postal code
print(df['Postal Code'].isna().sum())
# Out:
# 91

# %%
df.tail(5)
# Out:
#                                                Address  Beds  Baths  \
# 715        Lot 2019-1 3 Route, Brockway, New Brunswick   NaN    NaN
# 716     45 McAndrew ST, Moncton, New Brunswick, E1G4Z2   3.0    3.0
# 717        985 Vanier, Bathurst, New Brunswick, E2A3N3   4.0    1.0
# 718      490 Marguerite, Dieppe, New Brunswick, E1A7H1   3.0    2.0
# 719  564 Pleasant Vale RD, Elgin, New Brunswick, E4...   2.0    2.0
#
#      House Size  Lot Size                               Type   Price  \
# 715         NaN       NaN                Vacant Land           49900
# 716      1460.0       NaN              Single Family          389900
# 717         NaN       NaN              Single Family          139900
# 718      1806.0       NaN              Single Family          224900
# 719      1950.0       NaN              Single Family          289900
#
#     Postal Code
# 715         NaN
# 716      E1G4Z2
# 717      E2A3N3
# 718      E1A7H1
# 719      E4Z2C7

# %%
df.to_csv('houseprice_withpostalcodes.csv',index=False)
